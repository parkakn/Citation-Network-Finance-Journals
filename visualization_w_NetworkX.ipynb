# %%
import numpy as np
import pandas as pd
import re

# %% [markdown]
# ## Creating Citation Data

# %%
# Citing papers on GS
df_ref = pd.read_excel("data/JFE_GS_DATA.xlsx")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Citing papers on GS
# ----> 2 df_ref = pd.read_excel("data/JFE_GS_DATA.xlsx")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:517, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     511     raise ValueError(
#     512         "Engine should not be specified when passing "
#     513         "an ExcelFile - ExcelFile already has the engine set"
#     514     )
#     516 try:
# --> 517     data = io.parse(
#     518         sheet_name=sheet_name,
#     519         header=header,
#     520         names=names,
#     521         index_col=index_col,
#     522         usecols=usecols,
#     523         dtype=dtype,
#     524         converters=converters,
#     525         true_values=true_values,
#     526         false_values=false_values,
#     527         skiprows=skiprows,
#     528         nrows=nrows,
#     529         na_values=na_values,
#     530         keep_default_na=keep_default_na,
#     531         na_filter=na_filter,
#     532         verbose=verbose,
#     533         parse_dates=parse_dates,
#     534         date_parser=date_parser,
#     535         date_format=date_format,
#     536         thousands=thousands,
#     537         decimal=decimal,
#     538         comment=comment,
#     539         skipfooter=skipfooter,
#     540         dtype_backend=dtype_backend,
#     541     )
#     542 finally:
#     543     # make sure to close opened file handles
#     544     if should_close:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1629, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, date_format, thousands, comment, skipfooter, dtype_backend, **kwds)
#    1589 def parse(
#    1590     self,
#    1591     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)
#    1609     **kwds,
#    1610 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1611     """
#    1612     Parse specified sheet(s) into a DataFrame.
#    1613
#    (...)
#    1627     >>> file.parse()  # doctest: +SKIP
#    1628     """
# -> 1629     return self._reader.parse(
#    1630         sheet_name=sheet_name,
#    1631         header=header,
#    1632         names=names,
#    1633         index_col=index_col,
#    1634         usecols=usecols,
#    1635         converters=converters,
#    1636         true_values=true_values,
#    1637         false_values=false_values,
#    1638         skiprows=skiprows,
#    1639         nrows=nrows,
#    1640         na_values=na_values,
#    1641         parse_dates=parse_dates,
#    1642         date_parser=date_parser,
#    1643         date_format=date_format,
#    1644         thousands=thousands,
#    1645         comment=comment,
#    1646         skipfooter=skipfooter,
#    1647         dtype_backend=dtype_backend,
#    1648         **kwds,
#    1649     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:793, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, dtype_backend, **kwds)
#     790     sheet = self.get_sheet_by_index(asheetname)
#     792 file_rows_needed = self._calc_rows(header, index_col, skiprows, nrows)
# --> 793 data = self.get_sheet_data(sheet, file_rows_needed)
#     794 if hasattr(sheet, "close"):
#     795     # pyxlsb opens two TemporaryFiles
#     796     sheet.close()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_openpyxl.py:616, in OpenpyxlReader.get_sheet_data(self, sheet, file_rows_needed)
#     614 data: list[list[Scalar]] = []
#     615 last_row_with_data = -1
# --> 616 for row_number, row in enumerate(sheet.rows):
#     617     converted_row = [self._convert_cell(cell) for cell in row]
#     618     while converted_row and converted_row[-1] == "":
#     619         # trim trailing empty elements
#
# File ~\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:79, in ReadOnlyWorksheet._cells_by_row(self, min_col, min_row, max_col, max_row, values_only)
#      75 src = self._get_source()
#      76 parser = WorkSheetParser(src, self._shared_strings,
#      77                          data_only=self.parent.data_only, epoch=self.parent.epoch,
#      78                          date_formats=self.parent._date_formats)
# ---> 79 for idx, row in parser.parse():
#      80     if max_row is not None and idx > max_row:
#      81         break
#
# File ~\anaconda3\Lib\site-packages\openpyxl\worksheet\_reader.py:155, in parse()
#
# File ~\anaconda3\Lib\site-packages\openpyxl\worksheet\_reader.py:286, in openpyxl.worksheet._reader.WorkSheetParser.parse_row()
#
# File ~\anaconda3\Lib\site-packages\openpyxl\worksheet\_reader.py:228, in openpyxl.worksheet._reader.WorkSheetParser.parse_cell()
#
# File ~\anaconda3\Lib\site-packages\openpyxl\cell\text.py:180, in Text.content(self)
#     178 snippets = []
#     179 if self.plain is not None:
# --> 180     snippets.append(self.plain)
#     181 for block in self.formatted:
#     182     if block.t is not None:
#
# File ~\anaconda3\Lib\site-packages\openpyxl\descriptors\base.py:230, in Alias.__get__(self, instance, cls)
#     229 def __get__(self, instance, cls):
# --> 230     return getattr(instance, self.alias)
#
# KeyboardInterrupt:

# %%
df_ref = df_ref.iloc[:,1:]

# %%
df_ref

# %%
# Papers published on JFE 
jfe = pd.read_excel("data/Published_Papers_JFE.xlsx",index_col=0)

# %%
jfe

# %% [markdown]
# We can make several types of networks:
#
# 1. Author -> paper network
#     * nodes - authors, papers
#     * edges - authors worked on paper x
#     * Implication: collaboration network
#
# 2. Citations between papers
#     * nodes - papers (JFE, GS)
#     * edges - citations across papers
#     * Implication: citation network
#
# * Note: We have a lot of features:
#     * Papers with identified authors
#     * University of authors
#     * Country of authors
#     * Date of publication

# %% [markdown]
# Citation Network:

# %%
cit_ntwk = df_ref[['Cleaned Titles', 'cited_paper']].rename(columns={'Cleaned Titles': 'citing_paper'})

# %%
cit_ntwk

# %%
raw_df = pd.merge(cit_ntwk, jfe.rename(columns={'Title': 'cited_paper'}), 
                     on='cited_paper',how='right').dropna()

# %%
raw_df.to_csv("cit_ntwk_raw.csv")

# %%
merged_df = pd.merge(cit_ntwk, jfe.rename(columns={'Title': 'cited_paper'}), 
                     on='cited_paper',how='right').dropna()

# %%
merged_df = merged_df[['citing_paper','cited_paper','Date']]

# %%
merged_df
# Out:
#         citing_paper  cited_paper            Date
# 0             121413        21704   February 2024
# 1             183313        21704   February 2024
# 2             124760        21704   February 2024
# 3               2829        86470   February 2024
# 4              72332        86470   February 2024
# ...              ...          ...             ...
# 410809         15250        26077  September 2008
# 410810        116915        26077  September 2008
# 410811         22517        26077  September 2008
# 410812         96250        26077  September 2008
# 410813          6321        26077  September 2008
#
# [410772 rows x 3 columns]

# %%
merged_df.to_csv("cit_ntwk.csv")

# %%
merged_df.groupby('citing_paper').count().sort_values(by = 'cited_paper')
# Out:
#               cited_paper  Date
# citing_paper
# 0                       1     1
# 107049                  1     1
# 107047                  1     1
# 107044                  1     1
# 107042                  1     1
# ...                   ...   ...
# 91331                 160   160
# 106738                184   184
# 154096                259   259
# 150942                315   315
# 143017                537   537
#
# [184568 rows x 2 columns]

# %%
merged_df.groupby('citing_paper').count().sort_values(by = 'cited_paper').sum()
# Out:
# cited_paper    410772
# Date           410772
# dtype: int64

# %%
unique_cit = merged_df.groupby('citing_paper').count().sort_values(by = 'cited_paper')

# %%
unique_cit[unique_cit.cited_paper >1].sum()
# Out:
# cited_paper    306662
# Date           306662
# dtype: int64

# %% [markdown]
# Note that there are papers on Google Scholar citing multiple papers published on JFE. Motivates us to visualize the citation network where
# * Node: paper
# * Edge: paper-to-paper citation

# %% [markdown]
# ## NetworkX package

# %%
import numpy as np
import pandas as pd
import re
# Import the NetworkX package
import networkx as nx
from tqdm import tqdm

# %%
merged_df = pd.read_csv("cit_ntwk_raw.csv",index_col = 0)

# %%
df = merged_df[['citing_paper','cited_paper','Date']]

# %%
df
# Out:
#                                              citing_paper  \
# 0       dissecting mechanisms of financial crises: int...
# 1                   public liquidity and financial crises
# 2                               inefficient credit cycles
# 3                    learning and the capital age premium
# 4       investment, uncertainty, and u-shaped return v...
# ...                                                   ...
# 410809  kobi̇'lerin finansman sorunları ve çözüm öneri...
# 410810  finanțarea întreprinderilor mici și mijlocii d...
# 410811  relação entre estrutura de financiamento e açõ...
# 410812                              中国商业银行综合融资能力测度及影响因素分析
# 410813  коммерческий кредит и его особенности применит...
#
#                                               cited_paper            Date
# 0                      Delayed crises and slow recoveries   February 2024
# 1                      Delayed crises and slow recoveries   February 2024
# 2                      Delayed crises and slow recoveries   February 2024
# 3       Learning about the consumption risk exposure o...   February 2024
# 4       Learning about the consumption risk exposure o...   February 2024
# ...                                                   ...             ...
# 410809  Financing patterns around the world: Are small...  September 2008
# 410810  Financing patterns around the world: Are small...  September 2008
# 410811  Financing patterns around the world: Are small...  September 2008
# 410812  Financing patterns around the world: Are small...  September 2008
# 410813  Financing patterns around the world: Are small...  September 2008
#
# [410772 rows x 3 columns]

# %%
# Set to collect unique nodes
unique_nodes = set(df['citing_paper']) | set(df['cited_paper'])

# %%
unique_nodes
# Out:
# {'zur vertrauensökonomik: der interbankenmarkt in der krise von 2007-2009',
#  'nascent markets: understanding the success and failure of new stock markets',
#  'the existence of idiosyncratic risk in reits market',
#  'инвестиционные решения компаний в условиях асимметрии информации',
#  'unconventional monetary policy,(a) synchronicity and the yield curve',
#  'to what extent do environmental rating schemes capture climate goals?',
#  'imprecise and informative: lessons from market reactions to imprecise disclosure',
#  'the impact of changes of capital cost in enterprise valuation',
#  'stock markets during covid-19',
#  'georg schreyögg',
#  'disentangling shareholder risk aversion from leverage-dependent borrowing cost on corporate policies',
#  'reservation return and asset pricing inference',
#  'transmission of quantitative easing: the role of central bank reserves',
#  "«they'll just go to moody's»: investigating corporate credit rating updates using machine learning techniques",
#  'phasing out the gses',
#  'influence of globalization on the regional capital markets and consequences: evidence from warsaw stock exchange',
#  'an anatomy of the 2022 gilt market crisis',
#  'diffusion approximations for self-excited systems with applications to general branching processes',
#  'the effect of etfs on underlying stock markets: evidence from korea',
#  'the fall in shadow banking and the slow us recovery',
#  'option-implied expected equity returns and loan contracting',
#  'building state centrality through state selective financialization: reconfiguring the land reserve system in china',
#  'investor heterogeneity and factor pricing',
#  'endogenous intermediation in security lending networks',
#  '股票错误定价, 市值管理与上市公司并购行为',
#  'many-to-one contagion of economic growth rate across trade credit network of firms',
#  'who benefits from the leverage in lbos?',
#  'gpu prices and cryptocurrency returns',
#  'the power of love: emotional support and financial hardship',
#  'reputation, bailouts, and interest rate spread dynamics',
#  'banking deregulation and investment-cash flow sensitivity.',
#  'a study of a relationship between corporate solvency and stock returns of listed companies in the stock exchange of thailand',
#  'debt maturity choice of a firm: evidence from african countries',
#  'benchmark dataset for mid-price prediction of limit order book data',
#  '浅析半导体公司跨国设备投资的战略',
#  'red 2023-capítulo 4: política internacional del cambio climático y la conservación: retos de coordinación',
#  "local governance and business performance in vietnam: the transaction costs' perspective",
#  'profitability and capital adequacy approach for measuring impact of global financial crisis vis-à-vis indian banks',
#  "a practitioner's guide to yield curve modelling",
#  'crisis management and the credit rating agencies: the supervisory conflicts of the european securities and markets authority',
#  'corporate taxes, partisan politics, and stock returns',
#  'measuring and testing for the systemically important financial institutions',
#  'the impact of climate policy on oil and gas investment',
#  'the effect of stock market liquidity on stock returns: evidence from the nairobi securities exchange',
#  'cyclical behaviour of systemic risk in the banking sector',
#  'analyse de la relation entre la variation de la part de marché et la performance, passée et actuelle, chez les gestionnaires de fonds mutuels américains',
#  'the nexus of fdi, r&d, and human capital on chinese sustainable development: evidence from a two-step approach',
#  'fast and wild: bootstrap inference in stata using boottest',
#  "short selling and firms' disclosure of bad news: evidence from regulation sho",
#  'career concerns for revealing misreporting',
#  'do tone changes in financial statements predict acquisition behavior',
#  'distinguishing skills from luck in trading and investment',
#  'ceo 过度自信与企业创新',
#  'temporal-relational hypergraph tri-attention networks for stock trend prediction',
#  'systemic risk: what defaults are telling us',
#  'basis portfolios',
#  'internal governance and cost stickiness',
#  'ceo foreign experience and firm performance: does ceo tenure matter?',
#  'corporate tax behaviour and environmental disclosure: strategic trade-offs across elements of csr?',
#  'analysing corporate governance and accountability practices from an african neo-patrimonialism perspective: insights from kenya',
#  'capital allocation in developing countries',
#  'pricing vix options with wishart matrix affine jump diffusions while preserving consistency with spx options',
#  '在相关系数暧昧环境下的市场微观结构研究',
#  'eib working paper 2022/01: firm-level policy support during the crisis',
#  'research on the relationship between the heterogeneity of institutional investors and corporate r&d investment',
#  '股权集中度, 机构投资者与公司绩效—基于我国 a 股上市公司的实证研究',
#  'forecasting tourist arrivals using origin country macroeconomics',
#  'sovereign wealth funds–driving growth of the nuclear power sector',
#  'business shocks and corporate leverage',
#  'the value of political connections around the world: evidence from covid-19 economic lockdowns',
#  'what is the impact of bankrupt and restructured loans on japanese bank efficiency?',
#  'Real-time price discovery via verbal communication: Method and application to Fedspeak',
#  'greenhouse gas emissions and stock market volatility: an empirical analysis of oecd countries',
#  '政策不确定性的非线性宏观经济效应及其影响机制研究',
#  'equilibrium with a slow capital movement',
#  "different strokes for different folks: the moderating effect of top managers' political ideologies on the efficacy of top management team vertical pay disparities",
#  'capm, components of beta and the cross section of expected returns',
#  'when the issuer is an underwriter: the costs and benefits of underwriter choice',
#  'shareholder monitoring through voting: new evidence from proxy contests',
#  'mental time travel and financial investment valuation: exploring pricing asymmetries',
#  'uncertainty shocks, learning from prices and costly information acquisition',
#  'cultural tightness, conformity, and earnings comparability: evidence from china',
#  'do seo underwriters charge firms with weak shareholder rights more?',
#  'the effect of reverse factoring financial changes on supply chain',
#  'a tale of two option markets: pricing kernels and volatility risk',
#  'local institutions, external finance and investment decisions of small businesses in vietnam',
#  'do foreign investors promote stock price efficiency in emerging markets?',
#  'the influence of non-financial nation brand image dimensions on foreign direct investment inflows in zimbabwe',
#  "depositors' behaviour in times of mass deposit withdrawals",
#  'a practical approach to constructing price-based funding liquidity factors',
#  'does the threat of enforcement of financial regulations affect the cost of equity in weak institutional environments?',
#  'international capital inflows and firm r&d investment.',
#  'how does climate risk matter for corporate green innovation? empirical evidence from heavy-polluting listed companies in china',
#  'ownership structure and agency costs: evidence from the insurance industry in jordan',
#  'on the ranking consistency of systemic risk measures: empirical evidence',
#  'corporate governance and financial features of portuguese family firms',
#  'regulating ceo pay: evidence from the nonprofit revitalization act',
#  'financial development and cost of equity capital',
#  'rationalizing the dodd-frank clawback',
#  "china's anticorruption campaign and entrepreneurship",
#  'revenue diversification and bank profitability: study on indonesian banks',
#  'mutual fund activism and market regulation during the pre-ifrs period: the case of earnings informativeness in china from an ethical perspective',
#  'essays on macroeconomics with financial frictions',
#  'peer information comparability and corporate voting: evidence from voting on shareholder proposals',
#  'organizational capital and stock performance during crises: moderating role of generalist ceo',
#  'securities lending and corporate financing: evidence from bond issuance',
#  '负债融资对企业投资行为影响研究: 述评与展望',
#  'prediction of stock price based on fundamental, technical and economic factors',
#  "human capital and firm innovation: evidence from china's higher education expansion in the late 1990s",
#  'green bonds and corporate performance: a potential way to achieve green recovery',
#  'the unpriced information in fail-to-deliver short sales: implications for regulation and identifying limited arbitrage',
#  'does the us economic policy uncertainty connect financial markets? evidence from oil and commodity currencies',
#  'kolaborasi dan peran bank sentral di tengah pandemic covid-19',
#  "the ceo's cultural heritage affects bank performance under competition",
#  'a literature review on neurofinance',
#  'impact of capital structure on firm performance: empirical analysis of the jse top 40',
#  'optimal annuitization under stochastic interest rates',
#  'cross-border alliances and risk management',
#  'sell more with science: the mindsets, traits, and behaviors that create sales success',
#  'factors affecting oversubscription share',
#  'pengukuran nilai perusahaan dengan variabel keputusan investasi pada perusahaan property dan real estate',
#  'the roles of formal and informal institutions on innovations activity',
#  'kurumsal sosyal sorumluluk kavramının bibliyometrik analizi: 2017-2021 dönemine bir bakış',
#  'investor sentiment and speculative bond yield spreads',
#  'ceos',
#  'equity crowdfunding industry regulations in malaysia and indonesia: prospects and challenges during the covid-19 pandemic',
#  'relationship between stock over-valuation and corporate debt costs with considering the moderator variable of information asymmetry',
#  'the beneficial ownership report: stock returns and shareholder activism',
#  'The impact of arbitrage on market liquidity',
#  'market efficiency and foreign institutional trading: evidence from taiwan',
#  "advertising's monetary contribution to shareholder value",
#  'does it pay to have friends? social ties and executive appointments in banking',
#  "the ecb's new monetary policy strategy",
#  'green bond issuance frequency and corporate cost of capital',
#  'uncertainty, stock and commodity prices during the ukraine-russia war',
#  'does firm-level teamwork culture affect cash holdings?',
#  'the determinants of bank stability: an empirical investigation in southeast asia.',
#  'the inequality-debt-crisis nexus: exploring the missing political economy dimension',
#  'monitoring indirect contagion',
#  'dynamic connectedness amongst green bonds, pollution allowance policy, social responsibility and uncertainty',
#  'patent citations and stock performance: constructing a dynamic industry classification',
#  'public or private? determining the optimal ownership structure',
#  'macroeconomic determinants of household consumption expenditure in ghana: a multivariate cointegration approach',
#  'disconnecting financial misconduct: social connectedness and misconduct in financial advising',
#  'sticky decisions: anchoring and equity stakes in international acquisitions',
#  'the impact of product market competition on earnings quality',
#  'in the mood for risk? a random-assignment experiment addressing the effects of moods on risk preferences',
#  'corporate resilience to covid-19 crisis: the role of managerial bank-connected network',
#  'shareholder vs. director control over social policy matters: conflicting trends in corporate governance',
#  'bayesian semiparametric estimation of structural var models with stochastic volatility',
#  'should equity investors care about corporate bond prices? using bond prices to construct equity momentum strategies',
#  "the role of hfts in order flow toxicity and stock price variance, and predicting changes in hfts' liquidity provisions",
#  'forecasts on real yields and inflation expectations at the zero lower bound',
#  'determinants of environmental investment: evidence from europe',
#  'the effect of financial statement comparability on price discovery',
#  'trade credit and the speed of leverage adjustment',
#  'factores que influyen en la cultura ética de los colaboradores en las empresas que integran el sector del comercio al por menor—retail—en nuevo león',
#  'does the private equity financing improve performance in family smes?',
#  'implicit bank debt guarantees: costs, benefits and risks',
#  'papers in economics & finance',
#  'relationships between familiness, innovation and organizational performance in polish family businesses',
#  'factors timing factors',
#  'the changing behavior of the european credit default swap spreads during the covid-19 pandemic: a bayesian network analysis',
#  'smile‐implied hedging with volatility risk',
#  'do consumers need more protection from small‐dollar lenders? historical evidence and a roadmap for future research',
#  'managerial discretion, earnings opacity, and stock price informativeness',
#  'do individual investors trade stocks as gambling? evidence from repeated natural experiments',
#  'gvc centrality and productivity: are hubs key to firm performance?',
#  'what does futures market interest tell us about the macroeconomy and asset prices?',
#  'arquitectura homeostática: desarrollo metodológico para le evaluación ambiental de procesos constructivos en edificaciones',
#  'energy trading and its multiplicity of supervisors: effectiveness of fragmented supervision and information sharing in view of reporting obligations for energy\xa0…',
#  'audit fees, audit seasonality and audit quality in nigeria: a mediation analysis',
#  "türki̇ye'de makro i̇hti̇yati̇ poli̇ti̇kalarin bi̇reysel kredi̇ler üzeri̇ndeki̇ etki̇si̇ (7 li̇der banka anali̇zi̇)",
#  "social networks and reputation incentives: implications for directors' effort and firm valuation in sweden",
#  'new insights on computerized trading: implications of frequently revised trading decisions',
#  'costly financial advice: conflicts of interest or misguided beliefs',
#  'presidential candidates linguistic tone: the impact on the financial markets',
#  'generational differences of family businesses in mena countries: im-pact on indebtedness',
#  'passive investing and corporate governance: a law and economics analysis',
#  '中国上市公司资产增长异象的实证研究',
#  'es-cape-ing from overvalued sectors: sector selection based on the cyclically adjusted price-earnings (cape) ratio',
#  'the role of private equities in equity capital markets a short-and long-term quantitative study of european ipos',
#  'climate innovation and carbon emissions: evidence from the supply chain',
#  'bias reduction in spot volatility estimation from options',
#  'my global fund portfolio is not yours: the effect of home bias on european-and us-managed convertible bond fund exposures',
#  'cognitive diversity and inclusive leadership: redefining equity in the financial space',
#  'board structure and intragroup propping: evidence from family business groups in hong kong',
#  'proximity as enabler to crowd investors exploitation: a theoretical framework',
#  'the international commonality of idiosyncratic variances',
#  "essais sur l'impact des mesures de politique monétaire non conventionnelle dans la zone euro",
#  'does geographic focus reduce systematic risk in hotel reits?',
#  'suomen pankin ja finanssivalvonnan julkaisuarkisto kaisu',
#  'uncertainty of macroeconomic forecasters and the prediction of stock market bubbles',
#  'a timing momentum strategy',
#  'the role of knowledge, skills, and attitudes',
#  'dynamic spillovers in higher moments and jumps across etfs and economic and financial uncertainty factors in the context of successive shocks',
#  'essays on financial fragility and regulation',
#  'empirical study of market reaction to family enterprises, political affiliations and m&a activities.',
#  'regulatory capital is a panacea for efficiency, credit growth and reducing non-performing loans in commercial banks',
#  "uncertainty and ipo initial returns: evidence from the tone analysis of china's ipo prospectuses",
#  'trust busting: the effect of fraud on investor behavior',
#  "institutional investors' site visits and corporate social responsibility: implications for the extractive industries✰",
#  'does social communication make investors stay in the market?',
#  'multiple lenders, strategic default and the role of debt covenants',
#  "firms' financial and corporate governance characteristics association with earning management practices: a meta-analysis approach",
#  'роль корпоративного управления в инновационной деятельности компании',
#  'systemic risk analytics: a data-driven multi-agent financial network (mafn) approach',
#  'small and vulnerable? financial constraints during economic crises',
#  'does geographic proximity change the passiveness of institutional investors?',
#  'risk measures based on first four moments and resulting trading strategies',
#  'does ceo gender matter for bank risk?',
#  'lower partial moment and equity returns in borsa istanbul',
#  'operating cash flows and earnings target revision',
#  'decoding the great indian recapitalisation plan: restoring the health of public sector banks in india',
#  'do firms smooth their dividends over time? evidence from the johannesburg stock exchange',
#  'this file was downloaded from: http://eprints. qut. edu. au/63971',
#  'ceo succession planning and market reactions to ceo turnover announcements',
#  'ethics and banking: do banks divest their kind?',
#  'potential climate risks in financial markets: report from a workshop, january 20, 2016',
#  '주거래은행 집중도에 따른 부채비율과 이익조정의 관계',
#  '高管腐败, 传染效应与投资者保护——基于白培中腐败案的实证分析',
#  'access to funding by european banks and the financial crisis',
#  'the lack of strategic sustainability orientation in german water companies',
#  'r&d investments and firm value: evidence from china',
#  'hedging with regret',
#  'monetary policy and market interest rates: literature review using text analysis',
#  'academic abilities, trading and performance in the stock market',
#  'regulating deferred incentive pay',
#  'people management in entrepreneurial firms',
#  'does firm-level productivity predict stock returns?',
#  'the january effect, does options trading matter?',
#  'difference in responses to currency crisis between multinational firms and local firms: the use of foreign currency debt',
#  'a influência da criminalização do insider trading pela lei nº 10.303, de 31 de outubro de 2001, no custo de capital de companhias listadas na bm&fbovespa',
#  'accountant cfos and corporate tax avoidance',
#  'buku referensi variabel penelitian struktur modal teori dan empiris',
#  'does bank deposits volatility react to political instability in developing countries?',
#  'interbank market, stock market, and bank performance in east asia',
#  "what's trending in difference-in-differences? a synthesis of the recent econometrics literature",
#  'credit regimes and the seeds of crisis',
#  'tail risk, core risk, and expected stock returns',
#  'the best of both worlds: accessing emerging economies via developed markets',
#  "how does green policy affect polluting firms' dividend policy? the china experience",
#  'policy uncertainty, credit risk and unemployment in south africa',
#  'the economics of digital token cross-listings',
#  'uniform inference for conditional factor models with instrumental and idiosyncratic betas',
#  'the role of trading volume, open interest and trader positions on volatility transmission between spot and futures markets',
#  'causal factor investing: can factor investing become scientific?',
#  'financial anomalies: evidence from chinese a-share markets',
#  'uncovering the information content in abnormal institutional visits',
#  'when does the japan empowering women index outperform its parent and the esg select leaders indexes?',
#  'measuring the social responsibility discount for the cost of equity capital: evidence from benefit corporations',
#  "how has the post-9/11 gi bill affected veteran students' college loans? a longitudinal analysis of npsas using propensity score weighting",
#  'optimal consumption and investment with insurer default risk',
#  'an analysis of financial literacy and household saving among fishermen in indonesia',
#  'timing of predictions in dynamic cheap talk: experts vs. quacks',
#  'smells like animal spirits: the sensitivity of corporate investment to sentiment',
#  'improving the effectiveness of skills training programs',
#  'the visible hand when revenues stop: evidence from loan and stock markets during covid-19',
#  'high frequency trading: an overview',
#  'liquidity risk and the labor hiring premium',
#  "gamestop or game just started? leveling the playing field for social media meme investors to rebuild the public's trust",
#  'reputation and regulatory effects on director turnover and directorships',
#  'effects of rent default on real estate investment return in nairobi county, kenya',
#  'do bondholders receive benefits from bank interventions?',
#  'china and méxico: economic performance and religious ethical values',
#  'unspanned stochastic volatility from an empirical and practical perspective',
#  '(international) top managers–strategic implications for innovativeness, risk and digital transformation',
#  'the relationship between risk-neutral and actual default probabilities: the credit risk premium',
#  'central clearing valuation adjustment',
#  'the separation of ownership and control and its impact on corporate tax avoidance',
#  'the costs and benefits of performance fees in mutual funds',
#  'debt maturity structure and liquidity shocks',
#  'superior vs. inferior voting shares: price premium or discount?',
#  'green economy and credit quality in the european banking industry: what are the opportunities for sustainability?',
#  "the effect of analysts' inaccuracy on estimates of cost of capital$",
#  'patents as collateral assets in the wake of the global financial crisis',
#  'no arbitrage conditions in hjm multiple curve term structure models',
#  'female board participation and annual report readability in firms with boardroom connections',
#  'the precious metals holdings of chinese commercial banks',
#  'equity return expectations and financial wealth holdings of us households',
#  "ceo's incentives from control and cashflows",
#  'lecture notes in behavioral finance',
#  'investor demand in syndicated efsf/esm bond issuances',
#  "the effectiveness of e-corporate governance: an exploratory study of internet voting at shareholders' annual meetings in france",
#  'topics in finance: empirical methods in finance',
#  'the impact of ownership transferability on family firm governance and performance: the case of family trusts',
#  'a measurement approach to conservatism and earnings management',
#  'подходы к построению модели валютно-финансового регулирования в россии в условиях неустойчивости глобальных финансов (институциональные\xa0…',
#  'the social context of compensation design: social norms and the impact of equity incentives',
#  'how does tax policy influence corporate behavior? evidence from the restaurant industry',
#  'in defense of market efficiency: evidence from two million strategies',
#  'the prestige of stock exchanges and corporate cash holding in transition economies: a study on vietnamese listed firms',
#  'pengaruh modal awal investasi, pengetahuan investasi, sosial media influencer terhadap minat investasi mahasiswa akuntansi universitas tidar',
#  'detecting, analyzing and categorizing financial events in high frequency trading and its application',
#  'the effect of foreign investors on the cost of equity capital in korean stock market.',
#  'why home-based investing makes sense–evidence from the us market.',
#  'an overlapping generations model of taxpayer bailouts of banks',
#  'understanding the effect of advertising on stock returns and firm value: theory and evidence from a structural model',
#  'what is the cost of the apb 23 assertion? indefinitely reinvested foreign earnings, investment profitability, and financial reporting incentives',
#  'impacts of dynamic capital structure and ownership structure on distance to default: evidence from vietnam.',
#  'taxation of economic rents',
#  'the macroeconomic impact of financial and uncertainty shocks',
#  'to delegate or not to delegate? on the quality of voluntary corporate financial disclosure and its market impacts',
#  'an alter-centric perspective on status disparity and newcomer additions in multiparty syndicates',
#  'research advances in valuation and esg',
#  'the role of place and intellectual capital in achieving competitive advantage and improving performance of clothing small businesses',
#  'the eco-friendly side of analyst coverage: the case of green innovation',
#  'an examination of dynamic trading stategies in uk and us stock returns',
#  'financial strategies of small businesses to gain access to capital',
#  'funding structure, corporate governance and earnings management among listed commercial banks in sub-saharan africa',
#  'risk retention in securitisation and empty creditors: when financial regulation (positively) spills over corporate governance',
#  'the dynamics of bank rates in a negative-rate environment: the swiss case',
#  'acquisitions, labour turnover and wages',
#  'digital transformation along the supply chain',
#  'does being a socially responsible neighbor pay off? a peer effect perspective on corporate social responsibility and shareholder wealth',
#  'city innovation ability and internet infrastructure development: evidence from the “broadband china” policy',
#  'the dutch tulip mania: the social foundations of a financial bubble',
#  'gender diversity and financial statement fraud',
#  'the impact of environmentally responsible ceo on stakeholder values and financial performance',
#  'i̇şletmelerin yatırım kararları ile finansman kararları arasındaki ilişkinin değerlendirilmesi: türkiye imalat sektörü işletmeleri üzerine bir dinamik panel veri analizi',
#  'intersecting security, equity, and sustainability for transformation in the anthropocene',
#  'the rise of the equity lending market: implications for corporate financial policies',
#  'corporate leverage in emes: did the global financial crisis change the determinants?',
#  'meet, beat, and pollute',
#  'the importance of cultural tightness-looseness and government efficiency for understanding early covid-19 growth and death rates',
#  'financial reporting quality, private information, monitoring, and the lease-versus-buy decision',
#  'voluntary audit in small private banks',
#  'contractual inequality',
#  'does cybersecurity slow down digitization? a natural experiment of security breach notification laws',
#  'board structure, ownership structure and firm performance: a study of new zealand listed-firms',
#  'factores que inciden en la intención del cumplimiento tributario de las microempresas',
#  'why are most firms privately held',
#  'economic determinants of price informativeness about future earnings',
#  'are consumers international? a study of csr, cross-border shopping, commitment and purchase intent among online consumers',
#  'grzeszne spółki: synteza 15 lat badań teoretycznych i empirycznych',
#  'the unintended consequences of environmental tax for green innovation: evidence from china',
#  'self‐fulfilling liquidity dry‐ups',
#  'costly arbitrage and skewness pricing: evidence from first-day price limit reform in china',
#  'do fundamentals drive cryptocurrency prices?',
#  "executive equity risk-taking incentives and firms' choice of debt structure",
#  'accélérateur financier et politiques de stabilité financière dans la cemac',
#  'systemic risk: conditional distortion risk measures',
#  'overconfidence and corporate acquisitions: a study to the role of overconfidence in corporate acquisitions in the united kingdom',
#  'lost in the libor transition',
#  'locomotor-activated neurons of the cat. i. serotonergic innervation and co-localization of 5-ht7, 5-ht2a, and 5-ht1a receptors in the thoraco-lumbar spinal\xa0…',
#  'empirical investigations into systemic risk, economic growth and interdependence of factors in fama-french five factor asset pricing model',
#  'growth and inflation tradeoffs of dollarization: meta-analysis evidence',
#  'competition, efficiency, and stability in banking',
#  'working your tail off: active strategies versus direct hedging',
#  "1 caremark at the quarter-century watershed: modern-day compliance realities frame corporate directors' duty of good faith oversight, providing new dynamics\xa0…",
#  'olimpia carradori, margherita giuzio, sujit kapadia, dilyara salakhova, katia vozian',
#  'a framework for extracting the probability of default from listed stock option prices',
#  'the qualitative characteristics of accounting information, earnings quality, and islamic banking performance: evidence from the gulf banking sector',
#  'transparency regime initiatives and liquidity in the cds market',
#  'the roles of fintech with perceived mediators in consumer financial satisfaction with cashless payments',
#  'on the heterogeneity of private equity investors',
#  'credit traps and macroprudential leverage',
#  '管理层权力, 内部治理机制与企业绩效——基于中国上市公司面板数据的实证分析',
#  'politically connected ceos and earnings management: evidence from china',
#  'the future is bright–or is it?',
#  'distance, asymmetric information, and mortgage securitization',
#  "multi-business firms' corporate renewal decisions: divestiture governance mode choice of corporate spin-offs and equity carve-outs",
#  'the performance of taiwanese firms after a share repurchase announcement',
#  'the relationship of g-index and convertible debt issuance in the presence of restrictive covenants',
#  'bank competition, securitization, and risky investment',
#  "deposits as a stable source of bank funding. did the global finance crisis influence the banks' funding structure?",
#  'corporate social responsibility disclosure, dividend payments and firm value–relations and mediating effects',
#  'shhh... do gender diverse boards prioritize product market concerns over capital market incentives? an ethical dilemma',
#  "making a virtue of necessity? the economics and politics of the ecb's monetary policy, 1999-2019",
#  'corporate governance mechanisms and agency costs: cross-country analysis',
#  'discretionary credit rating and bank stability in a financial crisis',
#  'the economics of central clearing',
#  'dynamics of herding behavior and momentum effects: evidence from the iran capital market',
#  "more than words: fed chairs' communication during congressional testimonies",
#  'The high volume return premium and economic fundamentals',
#  'do we need dealers in otc markets?',
#  're-examining board reforms and firm value: response to “how much should we trust staggered differences-in-differences estimates?” by baker, larcker, and\xa0…',
#  'does societal trust make firms more trustworthy?',
#  'how do homeowners use interest-only mortgages',
#  'share pledging and financial constraints in china',
#  "study of the effectiveness of china's corporate governance reform–a board characteristics view",
#  'the pitfalls of central clearing in the presence of systematic risk',
#  'the impact of investor sentiment on equity returns: comparison between financial and non-financial sectors of pakistan stock exchange',
#  '企业年金参与决策的影响因素: 理论框架与实证分析——来自 a 股上市公司的经验证据',
#  'compensation consultants and the level, composition, and complexity of ceo pay',
#  'banking on bonds: the new links between states and markets',
#  'does differential taxation of short-term relative to long-term capital gains affect long-term investment?',
#  'acquiring distressed and bankrupt concerns',
#  'covid-19 and stock returns: evidence from malaysia',
#  'the contagion and competition effects of bank bailouts announced in october 2008',
#  'fintech lending tobias berg andreas fuster manju puri',
#  'wachstumsorientierte unternehmensgründungen-empirische analysen zum wechselspiel individueller und institutioneller determinanten',
#  'стратегии международных компаний: влияние факторов неопределенности',
#  'the effect of organizational culture and supplier integration to supply chain performance',
#  'capital flows, credit cycles and macroprudential policy',
#  'empirical capital market research in germany',
#  'the effect of internal control on green innovation: corporate environmental investment as a mediator',
#  'the independence of judges and corporate social responsibility',
#  'credit ratings and the investment channel of monetary policy',
#  'banking structures, liquidity and macroeconomic stability',
#  '离散累积前景理论下的投资组合选择',
#  'european sovereign debt crisisand the performance of dutch ipos',
#  "the implications of dependence, tail dependence, and bounds' measures for counterparty credit risk pricing",
#  'сентимент частных инвесторов в объяснении различий в биржевых характеристиках акций российского рынка',
#  'the secondary market of catastrophe bonds: seasonality, trading and returns',
#  'ceo risk aversion, firm risk and performance: evidence from deferred compensation returns around the 2008 financial crisis',
#  'the mediating effect of firm risk on corporate governance, firm performance, and earnings management',
#  'the foundation model approach of the australian energy regulator to estimating the cost of equity',
#  'affine point processes: refinements to large-time asymptotics',
#  'rating agencies as gatekeepers to the capital market: practical implications of 40 years of research',
#  'the influence of general strikes on stock market behavior',
#  'intraday market predictability: a machine learning approach',
#  'influence of institutional differences on trade credit use during pandemics',
#  'Oil volatility risk',
#  'managerial career concerns and informational stock price feedback',
#  'the impact of firm productivity on external finance',
#  'ceo-board dynamics',
#  'bond mutual fund and exchange-traded fund flows in stressed markets: empirical evidence on the destabilization hypothesis',
#  'joint modelling of s&p500 and vix indices with rough fractional ornstein-uhlenbeck volatility model',
#  'relationship between liquidity, asset quality, and profitability of mortgage banks in nigeria',
#  'relationship between return on assets and firm value: institutional holdings and firm size as moderators',
#  'do women directors improve firm performance? evidence from india',
#  'performance and incentives in mutual fund industry',
#  'a mechanism for the involvement of banks in not collateralized interbank markets',
#  'factors determining capital structure of pakistani non-financial firms',
#  'науково-методичні засади стратегічного управління фінансами банку в умовах невизначеності',
#  'disclosure and the outcome of securities litigation',
#  'a. exchanges and floor markets',
#  'a limited attention theory of time series momentum',
#  'corporate opacity and cost of debt for family firms',
#  "illiberal governance and the rise of china's public firms: an oxymoron or china's greatest triumph?",
#  'essays on financial macroeconomics and inequality',
#  '公司财务信息透明度, 内部人交易和股价特质性波动',
#  'ceo succession roulette',
#  'returning markets to the center of corporate law',
#  "articulating the masculine ideology and iconology of a gendered corporate 'bad-boy'entrepreneurial identity",
#  'in the eye of the storm: firms, putty-clay and capital destruction',
#  'the temperature effect and sovereign bond returns',
#  'asymmetric information and ahe securitization of sme loans',
#  'joão eduardo ribeiro',
#  'the myth of the credit spread puzzle',
#  'disaster response: the covid-19 pandemic and insider trading around the world',
#  'The cross section of conditional mutual fund performance in European stock markets',
#  'evaluating the interconnectedness of the sustainable development goals based on the causality analysis of sustainability indicators',
#  'the effect of institutional ownership on firms thrust to compete',
#  "technical trading rule profitability in currencies: it's all about momentum",
#  'essays on the information role of credit default swaps',
#  'testing strategies to increase saving in individual development account programs',
#  'does money help to rescue the consumption-capm?',
#  'long-term expected return of collectibles',
#  "india's conglomerate captains: top management team composition and internationalization at the tata group",
#  'the total costs of corporate borrowing in the loan market',
#  'can investment advisors promote rational investment? evidence from micro-data in china',
#  'an analysis of bank stress tests, shadow banking, and financial stability',
#  'the complex implications of fintech for financial inclusion',
#  'the economic consequences of discrete recognition and continuous measurement',
#  'financial market risk: measurement and analysis',
#  'evaluation of changes occurring in alm models of banks in poland after the outbreak of the covid-19 pandemic',
#  'stock market reactions to new product announcements: the role of investor sentiment',
#  'disagreement in expectations about public debt, monetary policy credibility and inflation risk premium',
#  'audit committee disclosure evolution: evidence from the field',
#  'voluntary sustainability assurance, capital constraint and cost of debt: international evidence',
#  'the ornstein-uhlenbeck process to model the deposit volume of non-maturing assets in colombia',
#  'pay for (individual) performance: issues, claims, evidence and the role of sorting effects',
#  'in regional science & economic geography',
#  'visualizing word categorization of corporate annual reports using self-organizing maps',
#  'how much control causes tunneling? evidence from china',
#  'risk-competition nexus: evidence from chinese banking industry',
#  'pushed past the limit? how japanese banks reacted to negative rates',
#  'bond convenience yields in the eurozone currency union',
#  'dynamic bayesian predictive synthesis in time series forecasting',
#  'clogged intermediation: were home buyers crowded out?',
#  'do technology alliance network characteristics promote ambidextrous green innovation? a perspective from internal and external pressures of firms in china',
#  'smooth regulatory intervention',
#  'single stock options and systematic volatility risk: evidence from india',
#  'do individual directors matter?',
#  "les effets macroéconomiques des mécanismes d'hystérèse et des politiques monétaires non conventionnelles",
#  "the size of the fed's balance sheet",
#  'governance of islamic financial institutions: the case of bangladesh',
#  '대량지분투자자는 유동성이 높은 주식에 투자하는가?: 외국인투자자와 국내투자자 비교를 중심으로',
#  'the impact of term limits on municipal borrowing costs',
#  'how does boardroom diversity influence the relationship between esg and firm financial performance?',
#  'an efficient algorithm for basket default swap valuation',
#  '“social” issues in takeovers',
#  'the emergence and pricing of green bonds in africa',
#  'efficiently backtesting conditional value-at-risk and conditional expected shortfall',
#  'demonstração do valor adicionado e informações esg',
#  'the value of managerial ability and general ability for inventor ceos',
#  'telegraph to tether: challenges in the global payments system and the struggle between private and public interests',
#  'investigation of the effect of earnings management on stock liquidity for the case of the tunisian stock exchange',
#  'venture financing and inefficient syndicates',
#  'incremental performance of an echannel addition: long-term and volatility consideration perspectives',
#  'crash worries and stock returns crash worries and stock returns',
#  'leverage and deepening business cycle skewness',
#  "stock liquidity, investment efficiency, and firm's performance: evidence from tehran stock exchange",
#  'can time‐varying risk premia and household heterogeneity explain credit cycles?',
#  'long run performance of rights issues and fpos: evidence from india',
#  'relative governance',
#  'bankruptcy protection duration and outcome of canadian public firms',
#  'corporate social (ir) responsibility towards employees and financial performance: using time to solve the chicken-egg problem',
#  'asset growth, style investing, and momentum',
#  'market effi ciency, short sales costs & constraints, and trading volume; a structural study',
#  'asset prices, news shocks, and the trade balance',
#  'the effect of money supply on the equity market index',
#  'implicit guarantees and risk taking inside financial institutions',
#  'pecuniary mistakes? payday borrowing by credit union members',
#  'three essays in finance: machine learning and finance applications',
#  'формування моделі концепції сталого розвитку життєздатного автотранспортного підприємства',
#  'reassessing anomalies and puzzles',
#  'foreign exchange market efficiency during covid-19 pandemic',
#  'estimating the rank of a beta matrix: a gmm approach 1',
#  'does market price sea level rise risk? evidence from high-tide flooding',
#  'board gender diversity and environmental emissions',
#  'working capital management, financial constraints and exports: evidence from european and us manufacturers',
#  'turnover premium, foreign institutional ownership, and time-varying risk premium in taiwan equity markets',
#  'is there a global safe haven?',
#  'first-move advantage in seasoned equity offerings: evidence from european banks',
#  'averting disaster: leverage limits for single-stock leveraged etfs',
#  'identifikacija cjenovnih skokova s pomoću procjenitelja integrirane varijance',
#  'rules and judgment in the oversight of bank accounting practices',
#  'estimando o custo de capital',
#  'the macroeconomic effects of housing wealth, housing finance, and limited risk sharing in general equilibrium',
#  'managerial skill and european pere fund performance',
#  'the complete guide to hedge funds and hedge fund strategies',
#  'stochastic continuous-time cash flows',
#  'signal incongruence and its consequences: a study of media disapproval and ceo overcompensation',
#  'it is not optimism when you know you are right: ceo optimism and self-attribution',
#  'does economic policy uncertainty drive the dynamic spillover among traditional currencies and cryptocurrencies? the role of the covid-19 pandemic',
#  'non-parametric and semi-parametric asset pricing: an application to the colombian stock exchange',
#  'when elites forget their duties: the double‐edged sword of prestigious directors on boards',
#  'patient capital outperformance: the investment skill of high active share managers who trade infrequently',
#  'do lower returns on bank stocks suggest lower cost of capital? an explanation for the low risk anomaly and the loan growth effect',
#  'housing cycles and exchange rates',
#  'essays on correlation modelling',
#  'accounting quality, debt covenants design and the cost of debt',
#  'tudy o',
#  'powerful ceos and their legacy: evidence from credit risk around ceo turnovers',
#  "farmers' demand for weather-based crop insurance contracts: the case of maize in south africa",
#  'wildcats in banking fields: the politics of financial inclusion',
#  'deciphering tax avoidance: evidence from credit rating disagreements',
#  'the role of taxes in forced ceo turnover',
#  'corporate venture capital portfolios and the implications of portfolio characteristics on venture innovative performance',
#  'on the fast track: information acquisition costs and information production',
#  'systemic risk and managerial overconfidence',
#  'sustainability and bank risk',
#  'involuntary excess reserve and heterogeneous transmission of policy rates to bank lending rates in china',
#  'sugar and spice and everything nice: what are independent directors made of? quoc-anh do sciences po',
#  'effect of shadow banking activities on firm risk and performance: entrusted loan evidence from chinese listed firms',
#  'foreign affiliates of the multinational firms in the wine and spirits industry: location-specific advantages and cultural distance',
#  'supervisory requirements and expectations for portfolio‐level counterparty credit risk measurement and management',
#  'a linear varying coefficient arch-m model with a latent variable',
#  '区域科技与金融有效结合模式及机制研究',
#  'funding liquidity risk and bank risk-taking in brics countries: an application of system gmm approach',
#  'optimization study on investment risk management of projects in private equity fund companies',
#  'asset issuance in over-the-counter markets',
#  'alternative portfolio methods',
#  'cfr working paper no. 16 working paper no. 16 working paper no. 16-03',
#  'aspects of individual financial decisionmaking',
#  'islamic financial literacy and its determinants: a field study on turkey',
#  'design of synthetic financial products in decentralized markets',
#  'survivorship bias in carry trading',
#  'certificados brancos para o caso português: análise económica e contributos para a sua aplicação e implementação',
#  'elaborative research between markowitz model and the index model',
#  'loan restructuring as a banking solution in the covid-19 pandemic: based on contingency theory',
#  'what makes hfts tick? tick size changes and information advantage in a market with fast and slow traders',
#  'ceo compensation, family control, and institutional investors in continental europe',
#  'a influência da mídia social no valor da petrobras',
#  'financial institutions and asset prices',
#  'обоснование применения методических инструментов риск-менеджмента в управлении стартапами',
#  'economic time series predictions and the illusion of support recovery',
#  'establishing esg as risk premia',
#  '媒体偏见与资产价格',
#  'the earnings/price risk factor in capital asset pricing models',
#  'does sentiment-based trading strategy yield profits?',
#  'extrinsic value',
#  'libor market model: how to account for the crisis?',
#  'information content when mutual funds deviate from benchmarks',
#  'us analyst regulation and the earnings forecast bias around the world',
#  'systemic risk shifting in financial networks',
#  'the impact of large-scale asset purchases on the s&p 500 index, long-term interest rates and unemployment',
#  'green dies in darkness? environmental externalities of newspaper closures',
#  'internal control and operational efficiency',
#  'bond yields',
#  "analyse d'impact de la réglementation (air) sur l'initiative parlementaire",
#  'managerial myopia and the mortgage meltdown',
#  'market response of us equities to domestic natural disasters: industry‐based evidence',
#  'do startup patent acquisitions affect inventor productivity?',
#  'covid-19 and fintech in latin america: impact and policy options',
#  'volatility risks implied from short term vix futures',
#  'facial structure and achievement drive: evidence from financial analysts',
#  'la finanza etica durante le crisi finanziarie del nuovo millennio: modelli teorici ed evidenze empiriche',
#  'diversity and performance in entrepreneurial teams',
#  'similarities between stock price correlation networks and co-main product networks: threshold scenarios',
#  'a flow-based explanation for return predictability',
#  'ambiguity—risk—return: evidence from the stock market in china',
#  'the impact of corporate governance and agency effect on earnings management–a test of the dual banking system',
#  'strumenti di de-biasing per la mitigazione degli errori comportamentali nelle negoziazioni di borsa.',
#  'venture capital, angel financing, and crowdfunding of entrepreneurial ventures: a literature review',
#  'performance management, broadband technology, and restructuring–econometric analyses using linked-employer-employee data',
#  'on hedge fund inceptions in a competitive market',
#  'director independence and corporate investment efficiency: evidence from board reforms worldwide',
#  'information in (and not in) the term structure',
#  'women on indian boards and market performance: a role-congruity theory perspective',
#  'trading strategies in futures markets',
#  'bildiriler kitabi',
#  'reit stock dividends: the policy and intra‐industry wealth effects',
#  'do economic forecasters believe the stock market is efficient? evidence from germany',
#  'do fiscal varia bles affect stock market returns in eu countries?',
#  'better cross hedges with composite hedging? hedging equity portfolios using financial and commodity futures',
#  'are returns to r&d in the global services industry impervious to business environment turbulence?',
#  'governance through threat: does short selling improve internal governance?',
# ...
#  'monetary policy on financing zombie firms: evidence from europe',
#  'leveraging on home bias. large stakes and long-termism by swedish institutional investors sophie nachemson-ekwall',
#  'overinvestment–a new measure of discretionary accruals',
#  'executive social connections and gender pay gaps',
#  'the mean–variance relation and the role of institutional investor sentiment',
#  'corporate governance and financial stability: the case of commercial banks in vietnam',
#  'sticking to your plan: the role of present bias for credit card paydown',
#  'Understanding commonality in liquidity around the world',
#  'investor reaction to positive and negative corporate social events',
#  '2008 krizi sonrası batı bankacılık sektöründe ortaya çıkan finansman temin şekillerinin analizi ve türk bankacılık sektöründe uygulanabilirliliği',
#  '世界金融危機後の国際銀行フロー: 何が明らかにされたのか',
#  'perception eccentricities in risk time dimension of construction professionals in the state of kuwait',
#  'venture capital investments, merger activity, and competition laws around the world',
#  'uncovered equity parity: theory and evidence from the g-7',
#  "the role of esg in acquirers' performance change after m&a deals",
#  'information or noise: what does algorithmic trading incorporate into the stock prices?',
#  'internal governance and corporate acquisition activities',
#  'economic news and the cross-section of commodity futures returns',
#  'bank stress test results and their impact on consumer credit markets',
#  "all in the family? the impact of founder directors and family governance on microfinance institutions' social performance",
#  'time-varying effect of macro-prudential policies on household credit growth: evidence from china',
#  "doing business while holding public office: evidence from mozambique's firm registry",
#  'water stress & water salience: implications for water supply planning',
#  'multiatsm package-general guidelines',
#  'does social capital mitigate managerial self-dealing? evidence from insider trading',
#  'jacks-of-all-trades? the effect of balanced skills on team performance',
#  'consumption taxes and corporate investment',
#  'does broadband internet infrastructure mitigate firm-level economic policy uncertainty? evidence from the broadband china pilot policy',
#  'the effect of labor cost on innovation',
#  'the role of customer and expert ratings in a hedonic analysis of french red wine prices: from gurus to geeks?',
#  'two sides of the same coin: disentangling the coinsurance effect and the diversification discount in m&a transactions$',
#  'essays on threat of employee mobility and firm countervailing strategies',
#  'predicting stock market returns with machine learning',
#  'intangibles and the uk under-investment puzzle: evidence from firm-level panel data',
#  'forecasting daily exchange rates: a comparison between ssa and mssa',
#  'the importance of targets and value creation in vertical acquisitions',
#  'diversity among norwegian boards of directors: does a quota for women improve firm performance?',
#  'multilatinas: a systematic literature review',
#  'equity value, bankruptcy, and optimal dividend policy with finite maturity-variational inequality approach with discontinuous coefficient',
#  'does information asymmetry affect corporate tax aggressiveness?',
#  'the influencing mechanism of internal control effectiveness on technological innovation: csr as a mediator. sustainability 2021, 13, 13122',
#  'business models and their impact on bank performance: a long-term perspective',
#  'three chapters on investments and financial institutions',
#  'creditor protection, shareholder protection and investment efficiency: new evidence',
#  'asset recognition and differential information content in capitalized and expensed r&d expenditures: evidence from corporate financing policies and\xa0…',
#  "pension fund's illiquid assets allocation under liquidity and capital constraints",
#  'good volatility vs. bad volatility: the asymmetric impact of financial depth on macroeconomic volatility',
#  'narcissistic leaders and corporate cash holdings: evidence in china',
#  'independent policy, dependent outcomes: a game of cross-country dominoes across european yield curves',
#  'financial reform in china: progress and challenges',
#  'economic policy uncertainty and information intermediary: the case of short seller',
#  'the post entry growth and survival of business startups: the role of founding teams',
#  'determinants of repo haircuts and bankruptcy',
#  "türkiye ve dünya'da varlık fonu bağımsız denetiminin karşılaştırılmalı olarak incelenmesi",
#  'the effect of the quality of corporate governance on the dividend policy of companies in the brics countries',
#  'assessing the effectiveness of government policies to stimulate the supply of early-stage risk capital: evidence from scotland',
#  'covid-19 and bank branch lending: the moderating effect of digitalization',
#  'market volatility and skewness risks in china',
#  'an uncertainty measure based on pearson correlation as well as a multiscale generalized shannon-based entropy with financial market applications',
#  'disclosure, competition and learning from asset prices',
#  'stock price synchronicity, cognitive biases, and momentum',
#  'the role of activism in corporate restructuring: the case study of elliott-edp',
#  'el papel de la liquidez en la valoración de activos financieros: el caso portugués',
#  'the effect of overconfidence and corporate governance on the acquisition premium',
#  'sovereign debt holding and bank sensitivity toward market risk: an alternative view of the bank-sovereign problem',
#  'gender quotas: challenging the boards, performance, and the stock market',
#  'preferences among expenditure: growth or short-term performance?',
#  "evaluation of the company's capital structure determining internal and external factors in baltic states during an economic shock",
#  'how do stronger creditor rights impact corporate acquisition activity and quality?',
#  'moods and aversions: regret, loss, risk and ambiguity in investment choices',
#  'xiqian zhang',
#  'seed stage it startup ecosystem analysis/submitted by alexander zöttl, bsc.',
#  'Investment and the weighted average cost of capital',
#  'precautionary volatility and asset prices',
#  'financial crises, income levels and access to finance',
#  'beta anomalies in scandinavian financial markets',
#  'why does volatility uncertainty predict equity option returns?',
#  'the effect of flood insurance on property values after a flood',
#  'global economy',
#  'are gender diverse boards more cautious? the impact of board gender diversity on sentiment in earnings press releases',
#  'Does risk management matter? Evidence from the U.S. agricultural industry',
#  'financial crises, bailouts and monetary policy in open economies',
#  "why companies are so different? alternative view on the firms' financial design",
#  'differential effects of politically-driven policy uncertainty on exchange rate performance',
#  'corporate foreign exchange speculation and integrated risk management',
#  'spacs como alternativa a las tradicionales salidas a bolsa. reflexiones desde la normativa española.',
#  'capital markets and short-termism: evidence from the investment behavior of public and private firms.',
#  'responses of international central banks to the covid-19 crisis',
#  'mergers and acquisitions: a review (part 2)',
#  'state-dependent variations in expected liquidity risk premium',
#  'information risk, market stress and institutional herding in financial markets: new evidence through the lens of a simulated model',
#  'quantifying the effects of new derivative introduction on exchange volatility, efficiency and liquidity',
#  'transport development, intellectual property rights protection and innovation: the case of the yangtze river delta region, china',
#  'shining a light on tax avoidance: how the panama papers created salience in a world crowded with good causes',
#  'printing away the mortgages: fiscal inflation and the post-covid housing boom',
#  'price discovery in bitcoin spot or futures?',
#  'ceo social capital and stock price informativeness: international perspective',
#  'ex ante efficient mechanism with private entry costs',
#  'statistical methods for high frequency financial data',
#  "pricing s&p 500 index options with l\\'evy jumps",
#  'transaction costs and impact of market timing on financing decisions: international evidence',
#  'culture, institutions, and financing choices: how and why are they related?',
#  'lokaljournalismus wie er sein sollte: wie sich lokaljournalist: innen ihre ideale zukunft vorstellen–eine systematische metaphernanalyse',
#  'applying salience theory to momentum strategies: euidence from the norwegian equity market 1992-2022',
#  "investors' appetite for money-like assets: the mmf industry after the 2014 regulatory reform",
#  "banks' cpital structure: european evidence",
#  'capitalizing on capitol hill: informed trading by hedge fund managers',
#  'efectos de la participación y esencia de la familia en la empresa: un análisis en la empresa familiar desde el enfoque de capacidades dinámicas',
#  'does monetary policy affect bank risk-taking?',
#  'determining factors influence company income tax with earning management as moderating variable',
#  'mampukah diversifikasi aset meningkatkan nilai pasar bank?',
#  'return on recent vc investment and long–run ipo returns',
#  'intellectual property rights policies of higher education institutions (heis) in india: a cross-sectional study',
#  '非对称业绩基准与高管薪酬: 基于代理成本视角',
#  'liquidity risk, bank networks, and the value of joining the fed',
#  'precautionary saving and liquidity shortage',
#  'the choice of financial advisors in cross-border mergers and acquisitions: determinants and consequences',
#  'the information content of option-based forecasts of volatility: evidence from the italian stock market',
#  'the local fractional bootstrap',
#  'dissecting and deciphering european option prices using closed-form series expansion',
#  'when fund flows take the fun (alpha) away',
#  'foreign institutional ownership and risk taking',
#  'business models in the search for efficiency: the case of public financial intermediaries',
#  "ministry of defenceit2-based multidimensional evaluation approach to the signaling: investors' priorities for the emerging industries",
#  'of stars and galaxies–co-authorship network and research',
#  'investors as regulators: green bonds and the governance challenges of the sustainable finance revolution',
#  'call feature and corporate bond yield spreads',
#  "the externality of taxing the 'rich': evidence from hedge funds",
#  'do financial market frictions hurt the performance of women‐led ventures? a meta‐analytic investigation',
#  'Why are US firms using more short-term debt?',
#  'threats of hostile takeover in context of the business economic security',
#  'innovation, intermediation, and the nature of entrepreneurship: a historical perspective',
#  'strategic flexibility and ceo compensation: evidence from technology peers',
#  'towards a positive attitude to money: designing an intervention to enhance wellbeing and reduce anxiety, with cross-cultural testing',
#  'how does the underlying affect the risk-return profiles of structured products?',
#  'the double trigger for mortgage default: evidence from the fracking boom',
#  'financial distress prediction using ga-bp neural network model',
#  'stock liquidity and the cost of equity capital in global markets',
#  'earnings quality measures and excess returns',
#  'matching finſech advice to participant needs: lessons and challenges',
#  'on size effects in separate accounts',
#  'investor leverage constraints and corporate risk taking',
#  'how liquid are liquid hedge funds?',
#  'shadow banking and financial regulation: a small-scale dsge perspective',
#  'foreign investor heterogeneity and stock liquidity across the world',
#  'an option to predict: why do deviations in put-call parity predict stock returns',
#  'effect of mobile network operator facilitated digital credit on the financial health of youth borrowers in kibera, nairobi county, kenya',
#  '企业集团对创新产出的影响: 来自制造业上市公司的经验证据',
#  'political information, firm value and information networks: evidence from the chinese national social security fund',
#  'measuring monetary policy and its impact on the bond market of emerging india',
#  'how interest rates are affected by relationship lending technology: a study on portuguese smes',
#  'cross-sectional performance persistence of mutual fund managers',
#  'back to the future: backtesting systemic risk measures during historical bank runs and the great depression',
#  'особенности развития современного предпринимательства в рамках концепции esg',
#  'kształtowanie struktury kapitałowej banków–stylizowane fakty z polskiego sektora bankowego',
#  "guanxi and networking: china's hidden business matrix",
#  'economic spillovers between related derivatives markets: the case of commodity and freight markets',
#  'winning a deal in private equity: do educational networks matter?',
#  'the cross market effects of short sale restrictions',
#  'corporate governance, excess-cash and firm value: evidence from asean-5',
#  'do debt contract enforcement costs affect financing and asset structure?',
#  'strategic ownership structure and the cost of debt',
#  'is the asymmetric impact of aggregate revenue and aggregate earnings on the stock index in accordance with the prospect theory?',
#  'pay inequality and annual report readability',
#  'the relevance of using cash flows and economic profit-based methods in capital budgeting: a focus on techniques–fcff\xa0…',
#  'financial distress risk in initial public offerings: how much do venture capitalists matter?',
#  'us monetary policy, commodity prices and the financialization hypothesis',
#  'internet appendix to: feedback loops in industry trade networks and the term structure of momentum profits',
#  'fiscal decentralization, enterprise digital transformation and enterprise green innovation—the case of 11 years a-share listed companies in china',
#  'housing demolition and financial market investment: evidence from chinese household data',
#  'credit risk and financial performance of banks in nigeria: moderating effect of board equity ownership',
#  'discussion of “audit committee financial expertise and earnings management: the role of status” by badolato, donelson, and ege (2014)',
#  'is the insurance industry systemically risky?',
#  'the implications of trader cognitive abilities on stock market properties',
#  'strategy and business model disclosure in corporate annual reports: a study of uk listed companies',
#  'how entrepreneurs hedge?',
#  'institutional monitoring and litigation risk: evidence from employee disputes',
#  'measuring deliberative conditions: an analysis of participant freedom and equality in federal open market committee deliberation',
#  'Financing constraints, home equity and selection into entrepreneurship',
#  'labor cost and corporate tax avoidance',
#  'board attributes and firm value: the moderating role of board meeting frequency',
#  'make-take decisions under high-frequency trading competition',
#  'j-liquidity measure: the term structure of the liquidity premium in japan',
#  'does working from home impact audit quality? evidence from non-pharmaceutical interventions during covid-19',
#  'denk bij harmonisatie insolventierecht na over effect op kredietverlening',
#  'long-term economic impact of disasters: evidence from multiple earthquakes in china',
#  'investment strategies with new classes of assets 2400-ensm068b',
#  'a cohort analysis of the investment performance of tiaa traditional annuities during working life',
#  'are mutual funds active voters?',
#  'the term structure of covered interest rate parity violations',
#  'in the shadow of shadow banking: a liquidity perspective',
#  'distracted analysts and earnings management',
#  'proprietary information spillovers and supplier choice: evidence from auditors',
#  'global liquidity, risk premiums and growth opportunities',
#  'asset liquidity and financial contracts: evidence from aircraft leases',
#  '债务融资能够在研发活动中发挥治理作用吗?',
#  ...}

# %%
paper_nodes = pd.DataFrame(unique_nodes, columns = ['Title'])
paper_nodes['name'] = ["node"+str(i) for i in range(len(paper_nodes))]
paper_nodes
# Out:
#                                                     Title        name
# 0       zur vertrauensökonomik: der interbankenmarkt i...       node0
# 1       nascent markets: understanding the success and...       node1
# 2       the existence of idiosyncratic risk in reits m...       node2
# 3       инвестиционные решения компаний в условиях аси...       node3
# 4       unconventional monetary policy,(a) synchronici...       node4
# ...                                                   ...         ...
# 186539  the rise of conscious consumers: the cash flow...  node186539
# 186540    an overview of the literature on upper echelons  node186540
# 186541  sustainability reporting and performance of me...  node186541
# 186542  women in monitoring positions and market risk....  node186542
# 186543  arbitrageur activity and market anticipation i...  node186543
#
# [186544 rows x 2 columns]

# %%
# Create a directed graph DG
G = nx.DiGraph()

# %%
# Set to collect unique nodes
unique_nodes = set(merged_df['citing_paper']) | set(merged_df['cited_paper'])

# Add nodes with attributes and add edges
with tqdm(total=len(unique_nodes)) as pbar:
    for node in unique_nodes:
        G.add_node(node, label='GS' if node in merged_df['citing_paper'].values else 'JFE')
        pbar.update(1)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 186544/186544 [37:46<00:00, 82.29it/s]

# %%
# Add edges from DataFrame
with tqdm(total=len(merged_df)) as pbar:
    for _, row in merged_df.iterrows():
        G.add_edge(row['citing_paper'], row['cited_paper'])
        pbar.update(1)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 410772/410772 [00:38<00:00, 10656.46it/s]

# %%
G.nodes['Delayed crises and slow recoveries']
# Out:
# {'label': 'JFE'}

# %%
# Export the graph to GML format
nx.write_graphml(G, "jfe_gs_citation_ntwk.graphml")

# %% [markdown]
# ---

# %% [markdown]
# ## Further Imrprovements

# %% [markdown]
# Citation network:
#
# * Nodes - papers (JFE or GS)
# * Edges - citation (directed)
#
# Use GS papers with only the identified authors.
#
# Should we do the same with identified JFE authors too?

# %%
gs_matches = pd.read_excel("data/JFE_citing_paper_author_matches.xlsx",index_col=0)

# %%
gs_matches
# Out:
#               Authors_x First Name Middle Name_x      Last Name  \
# 0       A krishnamurthy     Arvind           NaN  Krishnamurthy
# 4                 W li       Wendy          C.y.             Li
# 5                  W li      Wendy          C.y.             Li
# 6                  Z li       Zhan           NaN             Li
# 8                  K li        Kai           NaN             Li
# ...                 ...        ...           ...            ...
# 152487          C eckel    Carsten           NaN          Eckel
# 152525  S winston smith    Stanley             D          Smith
# 152538       R stehrer      Robert           NaN        Stehrer
# 152566           J kren      Janez           NaN           Kren
# 152567        M di maio    Michele            Di           Maio
#
#                    Authors_y  \
# 0       Arvind krishnamurthy
# 4              Wendy c.y. li
# 5              Wendy c.y. li
# 6                    Zhan li
# 8                     Kai li
# ...                      ...
# 152487         Carsten eckel
# 152525       Stanley d smith
# 152538        Robert stehrer
# 152566            Janez kren
# 152567       Michele di maio
#
#                                                University Source  \
# 0                                     stanford university  Abfer
# 4             Executive director moon economics institute   Cepr
# 5             Executive director moon economics institute   Cepr
# 6       Postdoctoral researcher in economics, national...   Cepr
# 8                          university of british columbia  Abfer
# ...                                                   ...    ...
# 152487  Professor of economics bibliothek wirtscharfts...   Cepr
# 152525                      university of central florida    Afa
# 152538  Scientific director the vienna institute for i...   Cepr
# 152566                      Doctoral researcher ku leuven   Cepr
# 152567  Professor of economics sapienza university of ...   Cepr
#
#        Middle Name_y  Country
# 0                NaN      USA
# 4               C.y.  Unknown
# 5               C.y.  Unknown
# 6                NaN    China
# 8                NaN   Canada
# ...              ...      ...
# 152487           NaN  Germany
# 152525             D      USA
# 152538           NaN  Austria
# 152566           NaN  Unknown
# 152567            Di     Rome
#
# [11396 rows x 9 columns]
